# %% [markdown]
# # Instacart-Style Data Preparation
#
# This notebook follows the same staged approach as the Instacart Basket Analysis scripts: systematic ingestion, cleaning, unification, and export of curated parquet datasets. Source files live in `Data/` and include store, web, and promo extracts.
#
# **What this notebook does**
# - Inspect XLSB files (sheets, headers) to align schemas.
# - Load raw promo, store, and web sales data.
# - Clean and standardize columns (dates, codes, strings, numeric types).
# - Merge sales across channels and optionally align with promo periods.
# - Persist clean parquet/CSV outputs for downstream analytics or ML.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import duckdb
from pyxlsb import open_workbook
import pyarrow as pa
import pyarrow.parquet as pq
import pyarrow.dataset as ds

pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 120)

# Project paths
PROJECT_ROOT = Path.cwd().parent  # notebook is stored in notebooks/
DATA_DIR = PROJECT_ROOT / "Data"
OUTPUT_DIR = PROJECT_ROOT / "tmp" / "processed"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

DATA_DIR, OUTPUT_DIR
# Out:
# (PosixPath('/Users/Glebazzz/MMS/Data'),
#  PosixPath('/Users/Glebazzz/MMS/tmp/processed'))

# %%
def excel_serial_to_datetime(series: pd.Series) -> pd.Series:
    """Convert Excel serial dates to pandas datetime, handling pre-parsed datetimes."""
    if pd.api.types.is_datetime64_any_dtype(series):
        return pd.to_datetime(series, errors="coerce")
    numeric = pd.to_numeric(series, errors="coerce")
    return pd.to_datetime(numeric, unit="D", origin="1899-12-30", errors="coerce")


def standardize_columns(df: pd.DataFrame) -> pd.DataFrame:
    """Normalize column names to snake_case and strip spaces."""
    df = df.copy()
    df.columns = (
        df.columns.str.strip()
        .str.lower()
        .str.replace(" ", "_", regex=False)
        .str.replace("/", "_", regex=False)
    )
    return df


def read_xlsb(path: Path, sheet: str | None = None) -> pd.DataFrame:
    """Read an XLSB file via pandas/pyxlsb."""
    return pd.read_excel(path, sheet_name=sheet or 0, engine="pyxlsb")


def inspect_xlsb(path: Path) -> dict:
    """Quickly inspect sheet names, headers, and row count without loading all data."""
    with open_workbook(path) as wb:
        sheets = wb.sheets
        first = sheets[0]
        with wb.get_sheet(first) as sh:
            headers = [c.v for c in next(sh.rows())]
            row_count = sum(1 for _ in sh.rows())
    return {"path": path.name, "sheets": sheets, "headers": headers, "rows": row_count}


def clean_sales_df(df: pd.DataFrame, channel: str, has_b2b: bool = False) -> pd.DataFrame:
    """Standardize sales data across store and web feeds."""
    df = standardize_columns(df)
    # Harmonize column names that differ between sources
    rename_map = {
        "sales_qty_anon": "sales_qty",
        "sales_value_anon": "sales_value",
        "margin_value_anon": "margin_value",
    }
    df = df.rename(columns=rename_map)
    # Convert dates from Excel serials
    df["date"] = excel_serial_to_datetime(df["date"])
    if "date_start_promo" in df.columns:
        df["date_start_promo"] = excel_serial_to_datetime(df["date_start_promo"])
    if "date_end_promo" in df.columns:
        df["date_end_promo"] = excel_serial_to_datetime(df["date_end_promo"])

    # Trim strings and unify types
    str_cols = [
        "channel",
        "department",
        "desc_group",
        "desc_subgroup",
        "desc_1_sku",
        "desc_2_sku",
        "desc_1_supplier",
        "desc_2_supplier",
        "brand",
    ]
    for col in str_cols:
        if col in df.columns:
            df[col] = df[col].astype(str).str.strip()

    df["channel"] = channel  # enforce channel label
    if not has_b2b:
        df["b2b"] = "NO"

    numeric_cols = [
        "code_department",
        "code_group",
        "code_subgroup",
        "cod_sku",
        "cod_supplier",
        "sales_qty",
        "sales_value",
        "margin_value",
    ]
    for col in numeric_cols:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce")

    return df


def clean_promo_df(df: pd.DataFrame) -> pd.DataFrame:
    """Prepare promo feed for merges."""
    df = standardize_columns(df)
    df["date"] = excel_serial_to_datetime(df["date"])
    df["date_start_promo"] = excel_serial_to_datetime(df.get("date_start_promo"))
    df["date_end_promo"] = excel_serial_to_datetime(df.get("date_end_promo"))

    string_like = [
        "channel",
        "code_promo",
        "desc_promo",
        "type_of_promo",
        "department",
        "desc_group",
        "desc_subgroup",
        "desc_1_sku",
        "desc_2_sku",
        "desc_1_supplier",
        "desc_2_supplier",
        "brand",
    ]
    for col in string_like:
        if col in df.columns:
            df[col] = df[col].astype(str).str.strip()

    numeric_cols = [
        "code_department",
        "code_group",
        "code_subgroup",
        "cod_sku",
        "cod_supplier",
        "sales_qty_anon",
        "sales_value_anon",
        "margin_value_anon",
    ]
    for col in numeric_cols:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce")

    # Drop potential header repeats / empty rows
    df = df[df["date"].notna()].reset_index(drop=True)
    return df

# %%
# Stream XLSB to Parquet to avoid RAM blow-ups

def _stream_xlsb_chunks(path: Path, chunk_size: int = 50_000):
    """Yield DataFrame chunks from an XLSB sheet."""
    with open_workbook(path) as wb:
        sheet_name = wb.sheets[0]
        with wb.get_sheet(sheet_name) as sh:
            rows_iter = sh.rows()
            header = [c.v for c in next(rows_iter)]
            batch = []
            for row in rows_iter:
                batch.append([c.v for c in row])
                if len(batch) >= chunk_size:
                    yield pd.DataFrame(batch, columns=header)
                    batch = []
            if batch:
                yield pd.DataFrame(batch, columns=header)


def stream_sales_xlsb_to_parquet(path: Path, out_path: Path, channel: str, has_b2b: bool = False, chunk_size: int = 50_000) -> int:
    """Stream a sales XLSB file to Parquet in chunks; return rows written."""
    writer = None
    total = 0
    for raw_df in _stream_xlsb_chunks(path, chunk_size):
        cleaned = clean_sales_df(raw_df, channel=channel, has_b2b=has_b2b)
        table = pa.Table.from_pandas(cleaned, preserve_index=False)
        if writer is None:
            writer = pq.ParquetWriter(out_path, table.schema)
        writer.write_table(table)
        total += len(cleaned)
    if writer:
        writer.close()
    return total


def stream_promo_xlsb_to_parquet(path: Path, out_path: Path, chunk_size: int = 50_000) -> int:
    """Stream a promo XLSB file to Parquet in chunks; return rows written."""
    writer = None
    total = 0
    for raw_df in _stream_xlsb_chunks(path, chunk_size):
        cleaned = clean_promo_df(raw_df)
        table = pa.Table.from_pandas(cleaned, preserve_index=False)
        if writer is None:
            writer = pq.ParquetWriter(out_path, table.schema)
        writer.write_table(table)
        total += len(cleaned)
    if writer:
        writer.close()
    return total

# %%
# Stream all raw files to Parquet (idempotent; run once, then reuse Parquet)
parquet_dir = OUTPUT_DIR / "raw_parquet"
parquet_dir.mkdir(parents=True, exist_ok=True)

promo_parquet = parquet_dir / "promo_full.parquet"
store_parquets = {
    "Stores_October-January_FY25.xlsb": parquet_dir / "stores_oct_jan.parquet",
    "Stores_February-June_FY25.xlsb": parquet_dir / "stores_feb_jun.parquet",
    "Stores_July-September_FY25.xlsb": parquet_dir / "stores_jul_sep.parquet",
}
web_parquets = {
    "Web_October-January_FY25.xlsb": parquet_dir / "web_oct_jan.parquet",
    "Web_February-August_FY25.xlsb": parquet_dir / "web_feb_aug.parquet",
    "Web_September_FY25.xlsb": parquet_dir / "web_sep.parquet",
}

# Promo
rows_promo = stream_promo_xlsb_to_parquet(DATA_DIR / "Promo_October-September_FY25.xlsb", promo_parquet)
print(f"Promo rows written: {rows_promo:,}")

# Stores
rows_store = 0
for fname, out_pq in store_parquets.items():
    rows_store += stream_sales_xlsb_to_parquet(DATA_DIR / fname, out_pq, channel="STORES")
print(f"Store rows written total: {rows_store:,}")

# Web
rows_web = 0
for fname, out_pq in web_parquets.items():
    rows_web += stream_sales_xlsb_to_parquet(DATA_DIR / fname, out_pq, channel="WEB", has_b2b=True)
print(f"Web rows written total: {rows_web:,}")
# Out:
# Promo rows written: 481,477
# Store rows written total: 2,617,146
# Web rows written total: 2,094,259

# %%
# Load from Parquet (fast, memory-friendly scanning) and build combined sales
sales_parquet_paths = list(store_parquets.values()) + list(web_parquets.values())

# Arrow dataset for lazy scans
sales_ds = ds.dataset(sales_parquet_paths, format="parquet")
promo_ds = ds.dataset([promo_parquet], format="parquet")

# Materialize to pandas only when needed; otherwise keep as Arrow/Parquet.
sales_df = sales_ds.to_table().to_pandas()
promo_df = promo_ds.to_table().to_pandas()

# Continue with existing logic
sales_df["date_year"] = sales_df["date"].dt.year
sales_df["date_month"] = sales_df["date"].dt.to_period("M")

print("rows", len(sales_df))
print(sales_df.groupby("channel").size())
sales_df.head()
# Out:
# rows 4711405
# channel
# STORES    2617146
# WEB       2094259
# dtype: int64
#   channel       date  code_department department  code_group desc_group  code_subgroup       desc_subgroup   cod_sku  \
# 0  STORES 2024-10-01              3.0         TV         3.0        LCD          122.0  TVC LCD FINO A 27P  173237.0
# 1  STORES 2024-10-01              3.0         TV         3.0        LCD          122.0  TVC LCD FINO A 27P  177909.0
# 2  STORES 2024-10-01              3.0         TV         3.0        LCD          122.0  TVC LCD FINO A 27P  178664.0
# 3  STORES 2024-10-01              3.0         TV         3.0        LCD          122.0  TVC LCD FINO A 27P  178665.0
# 4  STORES 2024-10-01              3.0         TV         3.0        LCD          122.0  TVC LCD FINO A 27P  180463.0
#
#                 desc_1_sku     desc_2_sku  cod_supplier        desc_1_supplier desc_2_supplier    brand  sales_qty  \
# 0     LG LCD24 24TQ510S BK   LED HD 5HDMI       20477.0  LG ELECTRONICS IT SPA      MONITOR TV       LG       15.0
# 1     LG LCD27 27TQ615S BK  LED FHD 2HDMI       20477.0  LG ELECTRONICS IT SPA      MONITOR TV       LG       12.0
# 2  PHILIPS LCD24 24PHS5537   LED HD 2HDMI       21141.0   TECHNOIT SPA/PHILIPS         PHILIPS  PHILIPS        1.0
# 3  PHILIPS LCD24 24PHS5507   LED HD 2HDMI       21141.0   TECHNOIT SPA/PHILIPS         PHILIPS  PHILIPS        0.0
# 4     LG LCD27 27TQ615S WH  LED FHD 2HDMI       20477.0  LG ELECTRONICS IT SPA      MONITOR TV       LG       10.0
#
#    sales_value  margin_value b2b  date_year date_month
# 0      2230.65       -123.33  NO       2024    2024-10
# 1      2177.41        237.16  NO       2024    2024-10
# 2       132.78        -13.02  NO       2024    2024-10
# 3        -9.43         -9.43  NO       2024    2024-10
# 4      1809.79        196.99  NO       2024    2024-10

# %%
# DuckDB aggregation directly on Arrow datasets (no full pandas load)
con = duckdb.connect()
con.register("sales_ds", sales_ds)
con.register("promo_ds", promo_ds)

# Row counts (lazy)
duckdb.query("SELECT COUNT(*) AS sales_rows FROM sales_ds").df()

# Monthly channel-level rollup (limited for display)
duckdb.query(
    """
    SELECT
      channel,
      date_part('year', date) AS year,
      date_trunc('month', date) AS month,
      SUM(sales_qty) AS qty,
      SUM(sales_value) AS sales_value,
      SUM(margin_value) AS margin
    FROM sales_ds
    GROUP BY 1, 2, 3
    ORDER BY 1, 2, 3
    LIMIT 50
    """
).df()
# Out:
#    channel  year      month          qty   sales_value        margin
# 0   STORES  2024 2024-10-01    1745154.0  1.464990e+08 -4.336592e+06
# 1   STORES  2024 2024-11-01    2205392.0  2.094295e+08 -1.846430e+07
# 2   STORES  2024 2024-12-01    2835758.0  2.285364e+08 -1.168949e+07
# 3   STORES  2025 2025-01-01    1678843.0  1.327959e+08 -2.891506e+06
# 4   STORES  2025 2025-02-01    1466751.0  1.166545e+08 -3.072959e+06
# 5   STORES  2025 2025-03-01    1581958.0  1.190871e+08 -3.756544e+06
# 6   STORES  2025 2025-04-01    1420352.0  1.102773e+08 -3.580728e+06
# 7   STORES  2025 2025-05-01    1528863.0  1.226788e+08 -7.275515e+06
# 8   STORES  2025 2025-06-01    1659073.0  1.310961e+08 -5.880098e+06
# 9   STORES  2025 2025-07-01    1762480.0  1.417559e+08 -7.194380e+06
# 10  STORES  2025 2025-08-01    1803944.0  1.373950e+08 -5.202006e+06
# 11  STORES  2025 2025-09-01    1650280.0  1.270310e+08 -3.406426e+06
# 12     WEB  2024 2024-10-01     186846.0  4.330561e+07 -4.604644e+06
# 13     WEB  2024 2024-11-01     333084.0  7.825355e+07 -1.056031e+07
# 14     WEB  2024 2024-12-01     378545.0  6.842791e+07 -7.560274e+06
# 15     WEB  2025 2025-01-01     188881.0  4.025755e+07 -4.190211e+06
# 16     WEB  2025 2025-02-01     161242.0  3.459434e+07 -4.125690e+06
# 17     WEB  2025 2025-03-01     147796.0  3.002741e+07 -3.050597e+06
# 18     WEB  2025 2025-04-01     143907.0  2.932252e+07 -3.212256e+06
# 19     WEB  2025 2025-05-01     154096.0  3.343149e+07 -5.379557e+06
# 20     WEB  2025 2025-06-01     161800.0  3.348649e+07 -4.390144e+06
# 21     WEB  2025 2025-07-01     173695.0  3.882598e+07 -6.078854e+06
# 22     WEB  2025 2025-08-01     154407.0  3.062855e+07 -3.306025e+06
# 23     WEB  2025 2025-09-01 -137228595.0 -7.211358e+10  1.449306e+10

# %%
# Join promos via DuckDB without loading all rows into pandas
sales_with_promo_out = OUTPUT_DIR / "sales_with_promo.parquet"

con.execute(
    f"""
    COPY (
      SELECT
        s.*,
        p.code_promo,
        p.desc_promo,
        p.type_of_promo,
        p.date_start_promo,
        p.date_end_promo,
        p.sales_qty_anon   AS promo_sales_qty,
        p.sales_value_anon AS promo_sales_value,
        p.margin_value_anon AS promo_margin_value
      FROM sales_ds s
      LEFT JOIN promo_ds p
        ON s.channel = p.channel
       AND s.cod_sku = p.cod_sku
       AND s.date BETWEEN p.date_start_promo AND p.date_end_promo
    ) TO '{sales_with_promo_out}' (FORMAT PARQUET);
    """
)

# Lightweight preview (no full load)
con.execute(f"SELECT * FROM read_parquet('{sales_with_promo_out}') LIMIT 20").df()
# Out:
#    channel       date  code_department department  code_group desc_group  code_subgroup         desc_subgroup  \
# 0   STORES 2024-10-01              3.0         TV         3.0        LCD          122.0    TVC LCD FINO A 27P
# 1   STORES 2024-10-01              3.0         TV         3.0        LCD          122.0    TVC LCD FINO A 27P
# 2   STORES 2024-10-01              3.0         TV         3.0        LCD          122.0    TVC LCD FINO A 27P
# 3   STORES 2024-10-01              3.0         TV         3.0        LCD          122.0    TVC LCD FINO A 27P
# 4   STORES 2024-10-01              3.0         TV         3.0        LCD          122.0    TVC LCD FINO A 27P
# 5   STORES 2024-10-01              3.0         TV         3.0        LCD          122.0    TVC LCD FINO A 27P
# 6   STORES 2024-10-01              3.0         TV         3.0        LCD          122.0    TVC LCD FINO A 27P
# 7   STORES 2024-10-01              3.0         TV         3.0        LCD          122.0    TVC LCD FINO A 27P
# 8   STORES 2024-10-01              3.0         TV         3.0        LCD          122.0    TVC LCD FINO A 27P
# 9   STORES 2024-10-01              3.0         TV         3.0        LCD          122.0    TVC LCD FINO A 27P
# 10  STORES 2024-10-01              3.0         TV         3.0        LCD          122.0    TVC LCD FINO A 27P
# 11  STORES 2024-10-01              3.0         TV         3.0        LCD          124.0  TVC LCD DA 28P A 32P
# 12  STORES 2024-10-01              3.0         TV         3.0        LCD          124.0  TVC LCD DA 28P A 32P
# 13  STORES 2024-10-01              3.0         TV         3.0        LCD          124.0  TVC LCD DA 28P A 32P
# 14  STORES 2024-10-01              3.0         TV         3.0        LCD          124.0  TVC LCD DA 28P A 32P
# 15  STORES 2024-10-01              3.0         TV         3.0        LCD          124.0  TVC LCD DA 28P A 32P
# 16  STORES 2024-10-01              3.0         TV         3.0        LCD          124.0  TVC LCD DA 28P A 32P
# 17  STORES 2024-10-01              3.0         TV         3.0        LCD          124.0  TVC LCD DA 28P A 32P
# 18  STORES 2024-10-01              3.0         TV         3.0        LCD          124.0  TVC LCD DA 28P A 32P
# 19  STORES 2024-10-01              3.0         TV         3.0        LCD          124.0  TVC LCD DA 28P A 32P
#
#      cod_sku               desc_1_sku         desc_2_sku  cod_supplier            desc_1_supplier  desc_2_supplier  \
# 0   173237.0     LG LCD24 24TQ510S BK       LED HD 5HDMI       20477.0      LG ELECTRONICS IT SPA       MONITOR TV
# 1   177909.0     LG LCD27 27TQ615S BK      LED FHD 2HDMI       20477.0      LG ELECTRONICS IT SPA       MONITOR TV
# 2   178664.0  PHILIPS LCD24 24PHS5537       LED HD 2HDMI       21141.0       TECHNOIT SPA/PHILIPS          PHILIPS
# 3   178665.0  PHILIPS LCD24 24PHS5507       LED HD 2HDMI       21141.0       TECHNOIT SPA/PHILIPS          PHILIPS
# 4   180463.0     LG LCD27 27TQ615S WH      LED FHD 2HDMI       20477.0      LG ELECTRONICS IT SPA       MONITOR TV
# 5   186940.0  SAMSUNG LCD24 24N4300AD       LED HD 2HDMI       20072.0  SAMSUNG ELECTRONIC SPA CE       SAMSUNG CE
# 6   189981.0      PANA LCD24 24MS350E     LED WXGA 2HDMI       20424.0   PANASONIC MARKET.EU GMBH  PANASONIC BRUNO
# 7   217962.0    PEAQ LCD24 24GH-5024C                          21616.0          IMTRON ITALIA SRL   OK KOENIC PEAQ
# 8   222170.0     PEAQ LCD24 24H-5024E     Q-LED HD 3HDMI       21616.0          IMTRON ITALIA SRL   OK KOENIC PEAQ
# 9   339058.0     LG LCD24 24TQ510S WH       LED HD 2HDMI       20477.0      LG ELECTRONICS IT SPA       MONITOR TV
# 10  394012.0    PEAQ LCD24 24GH-7024C       LED HD 2HDMI       21094.0                   RECO SPA               OK
# 11  169192.0         LG LCD32 32LQ630  LED WXGA HD 2HDMI       24083.0         LG ELECTRONICS SPA            LG CE
# 12  170119.0       LG LCD32 32LQ63006      LED FHD 2HDMI       24083.0         LG ELECTRONICS SPA            LG CE
# 13  184961.0        SONY LCD32 32W800     LED WXGA 3HDMI       28085.0        SONY EUROPE B.V. TV             SONY
# 14  186935.0     SAMSUNG QLED32 32Q50     QLED FHD 3HDMI       20072.0  SAMSUNG ELECTRONIC SPA CE       SAMSUNG CE
# 15  186937.0    SAMSUNG LCD32 32T4300       LED HD 2HDMI       21327.0               ESPRINET SPA       SAMSUNG TV
# 16  186938.0   SAMSUNG LCD32 32T5372C     QLED FHD 2HDMI       21327.0               ESPRINET SPA       SAMSUNG TV
# 17  186942.0    SAMSUNG LCD32 32T4300       LED HD 2HDMI       20072.0  SAMSUNG ELECTRONIC SPA CE       SAMSUNG CE
# 18  188490.0       PEAQ LCD32 5023C-B                          21616.0          IMTRON ITALIA SRL   OK KOENIC PEAQ
# 19  188920.0     SAMSUNG QLED32 32Q50     QLED FHD 3HDMI       21327.0               ESPRINET SPA       SAMSUNG TV
#
#         brand  sales_qty  sales_value  margin_value b2b code_promo desc_promo type_of_promo date_start_promo  \
# 0          LG       15.0      2230.65       -123.33  NO       None       None          None              NaT
# 1          LG       12.0      2177.41        237.16  NO       None       None          None              NaT
# 2     PHILIPS        1.0       132.78        -13.02  NO       None       None          None              NaT
# 3     PHILIPS        0.0        -9.43         -9.43  NO       None       None          None              NaT
# 4          LG       10.0      1809.79        196.99  NO       None       None          None              NaT
# 5     SAMSUNG        4.0       636.44        -31.70  NO       None       None          None              NaT
# 6   PANASONIC        0.0         0.00          0.00  NO       None       None          None              NaT
# 7        PEAQ        2.0       179.76         38.66  NO       None       None          None              NaT
# 8        PEAQ       41.0      3212.45        606.41  NO       None       None          None              NaT
# 9          LG       11.0      1593.32        -83.64  NO       None       None          None              NaT
# 10       PEAQ       17.0      1838.17        344.74  NO       None       None          None              NaT
# 11         LG        9.0      1708.07        176.54  NO       None       None          None              NaT
# 12         LG       15.0      3150.56       -328.54  NO       None       None          None              NaT
# 13       SONY        5.0      1391.18        -67.76  NO       None       None          None              NaT
# 14    SAMSUNG        7.0      2157.49       -178.19  NO       None       None          None              NaT
# 15    SAMSUNG        1.0       178.50        -25.33  NO       None       None          None              NaT
# 16    SAMSUNG        1.0       219.09        -17.49  NO       None       None          None              NaT
# 17    SAMSUNG       10.0      2171.59         27.18  NO       None       None          None              NaT
# 18       PEAQ        2.0       187.23       -132.37  NO       None       None          None              NaT
# 19    SAMSUNG        2.0       470.48        -42.02  NO       None       None          None              NaT
#
#    date_end_promo  promo_sales_qty  promo_sales_value  promo_margin_value
# 0             NaT              NaN                NaN                 NaN
# 1             NaT              NaN                NaN                 NaN
# 2             NaT              NaN                NaN                 NaN
# 3             NaT              NaN                NaN                 NaN
# 4             NaT              NaN                NaN                 NaN
# 5             NaT              NaN                NaN                 NaN
# 6             NaT              NaN                NaN                 NaN
# 7             NaT              NaN                NaN                 NaN
# 8             NaT              NaN                NaN                 NaN
# 9             NaT              NaN                NaN                 NaN
# 10            NaT              NaN                NaN                 NaN
# 11            NaT              NaN                NaN                 NaN
# 12            NaT              NaN                NaN                 NaN
# 13            NaT              NaN                NaN                 NaN
# 14            NaT              NaN                NaN                 NaN
# 15            NaT              NaN                NaN                 NaN
# 16            NaT              NaN                NaN                 NaN
# 17            NaT              NaN                NaN                 NaN
# 18            NaT              NaN                NaN                 NaN
# 19            NaT              NaN                NaN                 NaN

# %%
# Quick file catalogue
xlsb_files = sorted(DATA_DIR.glob("*.xlsb"))
summary = pd.DataFrame([inspect_xlsb(path) for path in xlsb_files])
summary
# Out:
#                                 path       sheets                                            headers     rows
# 0  Promo_October-September_FY25.xlsb  [Anon Data]  [CHANNEL, CODE PROMO, DESC PROMO, DATE START P...   481478
# 1     Stores_February-June_FY25.xlsb  [Anon Data]  [CHANNEL, DATE, CODE DEPARTMENT, DEPARTMENT, C...  1046578
# 2    Stores_July-September_FY25.xlsb  [Anon Data]  [CHANNEL, DATE, CODE DEPARTMENT, DEPARTMENT, C...   655363
# 3   Stores_October-January_FY25.xlsb  [Anon Data]  [CHANNEL, DATE, CODE DEPARTMENT, DEPARTMENT, C...   915208
# 4      Web_February-August_FY25.xlsb  [Anon Data]  [CHANNEL, DATE, B2B, CODE DEPARTMENT, DEPARTME...   973258
# 5      Web_October-January_FY25.xlsb  [Anon Data]  [CHANNEL, DATE, B2B, CODE DEPARTMENT, DEPARTME...   964184
# 6            Web_September_FY25.xlsb  [Anon Data]  [CHANNEL, DATE, B2B, CODE DEPARTMENT, DEPARTME...   156820

# %%
# Load promo data
promo_path = DATA_DIR / "Promo_October-September_FY25.xlsb"
promo_raw = read_xlsb(promo_path)
promo_df = clean_promo_df(promo_raw)

promo_df.head()
# Out:
#   channel code_promo               desc_promo date_start_promo date_end_promo type_of_promo       date  \
# 0  STORES   1-250003  SPECIALE LA CASA PER ME       2024-10-14     2024-10-31       NO PEAK 2024-10-18
# 1  STORES   1-250003  SPECIALE LA CASA PER ME       2024-10-14     2024-10-31       NO PEAK 2024-10-18
# 2  STORES   1-250003  SPECIALE LA CASA PER ME       2024-10-14     2024-10-31       NO PEAK 2024-10-18
# 3  STORES   1-250003  SPECIALE LA CASA PER ME       2024-10-14     2024-10-31       NO PEAK 2024-10-18
# 4  STORES   1-250003  SPECIALE LA CASA PER ME       2024-10-14     2024-10-31       NO PEAK 2024-10-18
#
#    code_department                department  code_group      desc_group  code_subgroup              desc_subgroup  \
# 0               32        UTENSILI DA CUCINA         127          CUCINA            637                    PADELLE
# 1               32        UTENSILI DA CUCINA         127          CUCINA            645        PENTOLE A PRESSIONE
# 2               32        UTENSILI DA CUCINA         127          CUCINA            651                    PENTOLE
# 3               33  PICCOLI ELETTRODOMESTICI         121  ACCESSORI P.E.            629  BEVANDE IN CAPSULE/CIALDE
# 4               33  PICCOLI ELETTRODOMESTICI         121  ACCESSORI P.E.            629  BEVANDE IN CAPSULE/CIALDE
#
#    cod_sku                desc_1_sku              desc_2_sku  cod_supplier          desc_1_supplier desc_2_supplier  \
# 0   228050   LAGO SET PADEL C.NATURA                 5 PEZZI         21621  GROUPE SEB IT/LAGOSTINA       LAGOSTINA
# 1   228136    LAGO P/PRESS AMICA 5LT                                 21621  GROUPE SEB IT/LAGOSTINA       LAGOSTINA
# 2   127755  LAGOSTINA BATTERIA SMART  SET 9PZ BATTERIA SMART         21621  GROUPE SEB IT/LAGOSTINA       LAGOSTINA
# 3   119353       LAVAZZA CREMA&GUSTO             108 CAPSULE         20349              LAVAZZA SPA   LAVAZZA CAFFÈ
# 4   119359  LAVAZZA ESPRES.PASSIONAL             108 CAPSULE         20349              LAVAZZA SPA   LAVAZZA CAFFÈ
#
#        brand  sales_qty_anon  sales_value_anon  margin_value_anon
# 0  LAGOSTINA               8               399              52.53
# 1  LAGOSTINA               8               317             -85.64
# 2  LAGOSTINA               3               273              30.74
# 3    LAVAZZA              34               775              80.45
# 4    LAVAZZA              17               393              39.73

# %%
# Load store sales (three fiscal windows)
store_files = [
    "Stores_October-January_FY25.xlsb",
    "Stores_February-June_FY25.xlsb",
    "Stores_July-September_FY25.xlsb",
]
store_frames = []
for fname in store_files:
    path = DATA_DIR / fname
    raw = read_xlsb(path)
    cleaned = clean_sales_df(raw, channel="STORES")
    store_frames.append(cleaned)

stores_df = pd.concat(store_frames, ignore_index=True)
stores_df.head()

# %%
# Load web sales
web_files = [
    "Web_October-January_FY25.xlsb",
    "Web_February-August_FY25.xlsb",
    "Web_September_FY25.xlsb",
]
web_frames = []
for fname in web_files:
    path = DATA_DIR / fname
    raw = read_xlsb(path)
    cleaned = clean_sales_df(raw, channel="WEB", has_b2b=True)
    web_frames.append(cleaned)

web_df = pd.concat(web_frames, ignore_index=True)
web_df.head()
# Out:
#   channel       date b2b  code_department                department  code_group      desc_group  code_subgroup  \
# 0     WEB 2024-10-01  NO               33  PICCOLI ELETTRODOMESTICI         121  ACCESSORI P.E.            629
# 1     WEB 2024-10-01  NO               33  PICCOLI ELETTRODOMESTICI         125      PED CUCINA            677
# 2     WEB 2024-10-01  NO               30                 ACCESSORI          78            CAVI            461
# 3     WEB 2024-10-01  NO               30                 ACCESSORI          78            CAVI            461
# 4     WEB 2024-10-01  NO               30                 ACCESSORI          78            CAVI            461
#
#                desc_subgroup  cod_sku                desc_1_sku             desc_2_sku  cod_supplier  \
# 0  BEVANDE IN CAPSULE/CIALDE   365253  SODA CON.LIMONE ZERO 440                    nan         20577
# 1                      MIXER   614318        ARIETE MIXER PIMMY                   200W         20286
# 2                ACC.ELETTR.   187192    POLYP ADATT 433 BIANCO  BLISTER SPINA 10A-16A         22875
# 3                ACC.ELETTR.   187192    POLYP ADATT 433 BIANCO  BLISTER SPINA 10A-16A         22875
# 4                ACC.ELETTR.   187192    POLYP ADATT 433 BIANCO  BLISTER SPINA 10A-16A         22875
#
#              desc_1_supplier        desc_2_supplier       brand  sales_qty  sales_value  margin_value
# 0  SODASTREAM INT.BVIT.BRANC  SODASTREAM WASSERMAXX  SODASTREAM          1         0.99         -3.75
# 1   DE LONGHI APPLIANCES SRL                 ARIETE      ARIETE          1         0.87        -15.51
# 2               POLYPOOL SPA       POLYPOOL QUALITY    POLYPOOL          1         1.76          0.41
# 3               POLYPOOL SPA       POLYPOOL QUALITY    POLYPOOL          1         1.92          0.45
# 4               POLYPOOL SPA       POLYPOOL QUALITY    POLYPOOL          1         1.70          0.40

# %%
# Combine sales across channels
sales_df = pd.concat([stores_df, web_df], ignore_index=True)

# Basic sanity checks
sales_df["date_year"] = sales_df["date"].dt.year
sales_df["date_month"] = sales_df["date"].dt.to_period("M")

print("rows", len(sales_df))
print(sales_df.groupby("channel").size())
sales_df.head()
# Out:
# rows 4711405
# channel
# STORES    2617146
# WEB       2094259
# dtype: int64
#   channel       date  code_department department  code_group desc_group  code_subgroup       desc_subgroup  cod_sku  \
# 0  STORES 2024-10-01                3         TV           3        LCD            122  TVC LCD FINO A 27P   173237
# 1  STORES 2024-10-01                3         TV           3        LCD            122  TVC LCD FINO A 27P   177909
# 2  STORES 2024-10-01                3         TV           3        LCD            122  TVC LCD FINO A 27P   178664
# 3  STORES 2024-10-01                3         TV           3        LCD            122  TVC LCD FINO A 27P   178665
# 4  STORES 2024-10-01                3         TV           3        LCD            122  TVC LCD FINO A 27P   180463
#
#                 desc_1_sku     desc_2_sku  cod_supplier        desc_1_supplier desc_2_supplier    brand  sales_qty  \
# 0     LG LCD24 24TQ510S BK   LED HD 5HDMI         20477  LG ELECTRONICS IT SPA      MONITOR TV       LG         15
# 1     LG LCD27 27TQ615S BK  LED FHD 2HDMI         20477  LG ELECTRONICS IT SPA      MONITOR TV       LG         12
# 2  PHILIPS LCD24 24PHS5537   LED HD 2HDMI         21141   TECHNOIT SPA/PHILIPS         PHILIPS  PHILIPS          1
# 3  PHILIPS LCD24 24PHS5507   LED HD 2HDMI         21141   TECHNOIT SPA/PHILIPS         PHILIPS  PHILIPS          0
# 4     LG LCD27 27TQ615S WH  LED FHD 2HDMI         20477  LG ELECTRONICS IT SPA      MONITOR TV       LG         10
#
#    sales_value  margin_value b2b  date_year date_month
# 0      2230.65       -123.33  NO       2024    2024-10
# 1      2177.41        237.16  NO       2024    2024-10
# 2       132.78        -13.02  NO       2024    2024-10
# 3        -9.43         -9.43  NO       2024    2024-10
# 4      1809.79        196.99  NO       2024    2024-10
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Optional: promo preview without full pandas merge (avoid OOM)
promo_join_parquet = OUTPUT_DIR / "sales_with_promo.parquet"

if promo_join_parquet.exists():
    # Sample from precomputed DuckDB join
    sales_with_promo = pd.read_parquet(promo_join_parquet)
    sales_with_promo.head(20)
else:
    preview = duckdb.query(
        """
        SELECT
          s.*,
          p.code_promo,
          p.desc_promo,
          p.type_of_promo,
          p.date_start_promo,
          p.date_end_promo
        FROM sales_ds s
        LEFT JOIN promo_ds p
          ON s.channel = p.channel
         AND s.cod_sku = p.cod_sku
         AND s.date BETWEEN p.date_start_promo AND p.date_end_promo
        LIMIT 20
        """
    ).to_df()
    preview

# %%
# Persist curated outputs
promo_out = OUTPUT_DIR / "promo_clean.parquet"
sales_out = OUTPUT_DIR / "sales_clean.parquet"
sales_with_promo_out = OUTPUT_DIR / "sales_with_promo.parquet"

promo_df.to_parquet(promo_out, index=False)
sales_df.to_parquet(sales_out, index=False)
sales_with_promo.to_parquet(sales_with_promo_out, index=False)

# Lightweight CSVs for quick inspection (first 50k rows to keep size manageable)
(promo_df.head(50_000)).to_csv(OUTPUT_DIR / "promo_clean_sample.csv", index=False)
(sales_df.head(50_000)).to_csv(OUTPUT_DIR / "sales_clean_sample.csv", index=False)

promo_out, sales_out, sales_with_promo_out

# %% [markdown]
# **How to run**
# 1. Install deps (inside project env): `pip install pandas pyxlsb pyarrow`.
# 2. Open this notebook from the repo root with Jupyter or VS Code and run all cells.
# 3. Cleaned parquet/CSV files will appear in `tmp/processed/` for downstream use (e.g., DuckDB, analytics, or model training).

# %%
# Out:
#    channel      month        qty   sales_value        margin
# 0   STORES 2024-10-01  1745154.0  1.464990e+08 -4.336592e+06
# 1      WEB 2024-10-01   186846.0  4.330561e+07 -4.604644e+06
# 2   STORES 2024-11-01  2205392.0  2.094295e+08 -1.846430e+07
# 3      WEB 2024-11-01   333084.0  7.825355e+07 -1.056031e+07
# 4   STORES 2024-12-01  2835758.0  2.285364e+08 -1.168949e+07
# 5      WEB 2024-12-01   378545.0  6.842791e+07 -7.560274e+06
# 6   STORES 2025-01-01  1678843.0  1.327959e+08 -2.891506e+06
# 7      WEB 2025-01-01   188881.0  4.025755e+07 -4.190211e+06
# 8   STORES 2025-02-01  1466751.0  1.166545e+08 -3.072959e+06
# 9      WEB 2025-02-01   161242.0  3.459434e+07 -4.125690e+06
# 10  STORES 2025-03-01  1581958.0  1.190871e+08 -3.756544e+06
# 11     WEB 2025-03-01   147796.0  3.002741e+07 -3.050597e+06
# 12  STORES 2025-04-01  1420352.0  1.102773e+08 -3.580728e+06
# 13     WEB 2025-04-01   143907.0  2.932252e+07 -3.212256e+06
# 14  STORES 2025-05-01  1528863.0  1.226788e+08 -7.275515e+06
# 15     WEB 2025-05-01   154096.0  3.343149e+07 -5.379557e+06
# 16  STORES 2025-06-01  1659073.0  1.310961e+08 -5.880098e+06
# 17     WEB 2025-06-01   161800.0  3.348649e+07 -4.390144e+06
# 18  STORES 2025-07-01  1762480.0  1.417559e+08 -7.194380e+06
# 19     WEB 2025-07-01   173695.0  3.882598e+07 -6.078854e+06

# %%
from pathlib import Path
import duckdb, sqlite3, os

PROJECT_ROOT = Path("/Users/Glebazzz/MMS")
duck_db_path = PROJECT_ROOT / "tmp" / "mms_data.duckdb"

duck = duckdb.connect(duck_db_path)  # створить файл, якщо його ще немає
print("DB at:", duck_db_path)
# Out:
# DB at: /Users/Glebazzz/MMS/tmp/mms_data.duckdb
